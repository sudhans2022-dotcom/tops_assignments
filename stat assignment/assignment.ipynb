# %%
# Given the following columns from a mock Zomato restaurant dataset — Restaurant Name, Cuisine Type, Average Cost for Two,
# User Rating, City, and Open/Closed Status — classify each column as either Numerical (Continuous or Discrete) or Categorical (Nominal or Ordinal).
# 2.
# Create a table with 8 real-life examples (not from class) of data you might find in popular apps like Instagram, Flipkart or IRCTC. For each, specify the measurement scale
# (Nominal, Ordinal, Interval, or Ratio) and briefly explain your choice.<br><br><em><strong>Hint:</strong> Think about things like 'Order Status', 'Train Departure Time', 
# 'Number of Likes', or 'Payment Method'.</em>
# 3.
# Given this time-series data from a Spotify user's listening history — Date, Song Name, Play Count per Day — identify which columns represent time-series,
# and which are categorical or numerical. Explain your reasoning.
# 4.
# Write a function or pseudocode that takes a column of data (array of values) from a Flipkart order history and automatically detects whether it is likely Nominal,
# Ordinal, Interval, or Ratio scale. Briefly describe the logic used for each type.<br><br><em><strong>Constraint:</strong> You do not need to write a perfect algorithm — focus on 
# simple rules based on value types and patterns.</em>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# TASK 1----Given the following columns from a mock Zomato restaurant dataset — Restaurant Name, Cuisine Type, Average Cost for Two,
#     User Rating, City, and Open/Closed Status — classify each column as either Numerical (Continuous or Discrete) or Categorical (Nominal oOrdinal).

# %%
import pandas as pd
import numpy as np

# Mock Zomato-style dataset
data = {
    'Restaurant Name': ['Spice Villa', 'Pizza Hub', 'Curry House', 'Noodle Bar', 'Grill Point'],
    'Cuisine Type': ['Indian', 'Italian', 'Indian', 'Chinese', 'Continental'],
    'Average Cost for Two': [500, 800, 450, 600, 1200],
    'User Rating': [4.2, 3.8, 4.5, 3.9, 4.0],
    'City': ['Ahmedabad', 'Mumbai', 'Delhi', 'Ahmedabad', 'Bangalore'],
    'Open/Closed Status': ['Open', 'Closed', 'Open', 'Open', 'Closed']
}

df = pd.DataFrame(data)
df
# Out:
#   Restaurant Name Cuisine Type  Average Cost for Two  User Rating       City  \
# 0     Spice Villa       Indian                   500          4.2  Ahmedabad
# 1       Pizza Hub      Italian                   800          3.8     Mumbai
# 2     Curry House       Indian                   450          4.5      Delhi
# 3      Noodle Bar      Chinese                   600          3.9  Ahmedabad
# 4     Grill Point  Continental                  1200          4.0  Bangalore
#
#   Open/Closed Status
# 0               Open
# 1             Closed
# 2               Open
# 3               Open
# 4             Closed
